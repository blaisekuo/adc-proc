# %%
import matplotlib.pyplot as plt  
import pandas as pd  
import os
import numpy as np
from astropy.io import fits

# %%
x=np.arange(8)

# %%
plt.figure(figsize=(20, 10))
plt.plot(x,2*x)

# %%
np.arctan(1/2)
# Out:
# 0.4636476090008061
