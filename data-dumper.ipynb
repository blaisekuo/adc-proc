# %%
import yaml

#conda install pyyaml

# %%
event_timestamp_list = [
    ('20200114.061041','lam Tau - HD 25204','1.25'),
    ('20200114.061137','lam Tau - HD 25204','1.25'),
    ('20200114.061204','lam Tau - HD 25204','1.25'),
    ('20200114.061305','lam Tau - HD 25204','1.25'),
    ('20200114.061331','lam Tau - HD 25204','1.25'),
    ('20200114.061424','lam Tau - HD 25204','1.26'),
    ('20200114.061521','lam Tau - HD 25204','1.26'),
    ('20200114.061630','lam Tau - HD 25204','1.26'),
    ('20200114.061757','lam Tau - HD 25204','1.27'),
    ('20200114.061905','lam Tau - HD 25204','1.27'),
    ('20200114.061937','lam Tau - HD 25204','1.27'),
    ('20200114.062150','lam Tau - HD 25204','1.28'),
    ('20200114.062432','lam Tau - HD 25204','1.28'),
    ('20200114.062528','lam Tau - HD 25204','1.28'),
    ('20200114.062730','lam Tau - HD 25204','1.28'),
    ('20200114.062834','lam Tau - HD 25204','1.28'),
    ('20200114.062834','nu.02 CMa - HD 47205','1.59'),
    ('20200114.064427','nu.02 CMa - HD 47205','1.60'),
    ('20200114.064522','nu.02 CMa - HD 47205','1.60'),
    ('20200114.064605','nu.02 CMa - HD 47205','1.60'),
    ('20200114.064650','nu.02 CMa - HD 47205','1.60'),
    ('20200114.064901','nu.02 CMa - HD 47205','1.60'),
    ('20200114.065609','kap CMa - HD 50013','2.30'),
    ('20200114.070555','bet Tau - HD 35497','1.00'),
    ('20200114.070627','bet Tau - HD 35497','1.00'),
    ('20200114.070728','bet Tau - HD 35497','1.00'),
    ('20200114.070815','bet Tau - HD 35497','1.00'),
    ('20200114.070918','bet Tau - HD 35497','1.00'),
    ('20200114.070950','bet Tau - HD 35497','1.09'),
    ('20200114.071100','bet Tau - HD 35497','1.09'),
    ('20200114.071216','bet Tau - HD 35497','1.09'),
    ('20200114.071500','bet Tau - HD 35497','1.09'),
    ('20200114.071716','bet Tau - HD 35497','1.09'),
    ('20200114.071902','bet Tau - HD 35497','1.09'),
    ('20200114.072050','bet Tau - HD 35497','1.09'),
    ('20200114.072233','bet Tau - HD 35497','1.09'),
    ('20200114.072416','bet Tau - HD 35497','1.09'),
    ('20200114.072529','bet Tau - HD 35497','1.09'),
    ('20200114.072609','bet Tau - HD 35497','1.09'),
    ('20200114.072722','bet Tau - HD 35497','1.09'),
    ('20200114.072837','bet Tau - HD 35497','1.09'),
    ('20200114.072947','bet Tau - HD 35497','1.09'),
    ('20200114.073119','bet Tau - HD 35497','1.09'),
    ('20200114.073545','bet Tau - HD 35497','1.09'),
    ('20200114.073822','bet Tau - HD 35497','1.09'),
    ('20200114.074017','bet Tau - HD 35497','1.09'),
    ('20200114.074317','bet Tau - HD 35497','1.16'),
    ('20200114.074519','bet Tau - HD 35497','1.16'),
    ('20200114.074642','bet Tau - HD 35497','1.16'),
    ('20200114.074713','bet Tau - HD 35497','1.16'),
    ('20200114.074845','bet Tau - HD 35497','1.18'),
    ('20200114.075114','bet Tau - HD 35497','1.19'),
    ('20200114.075225','bet Tau - HD 35497','1.19'),
    ('20200114.075325','bet Tau - HD 35497','1.19'),
    ('20200114.075432','bet Tau - HD 35497','1.19'),
    ('20200114.075621','bet Tau - HD 35497','1.19'),
    ('20200114.075731','bet Tau - HD 35497','1.19'),
    ('20200114.080222','eta Uma - HD 120315','2.30'),
    ('20200114.080345','eta Uma - HD 120315','2.20'),
    ('20200114.080540','eta Uma - HD 120315','2.20'),
    ('20200114.080617','eta Uma - HD 120315','2.20'),
    ('20200114.080715','eta Uma - HD 120315','2.20'),
    ('20200114.080750','eta Uma - HD 120315','2.20'),
    ('20200114.080829','eta Uma - HD 120315','2.14'),
    ('20200114.080923','eta Uma - HD 120315','2.13'),
    ]

# %%
raunche_def = {
    'timestamp': 'default',
    'goffset_stellar_centroidx': 0,
    'goffset_stellar_centroidy': 0,
    'hafbox': 40,
    'bigbox': 250,
    'h1r': (50,100),
    'h2r': (250,300),
    'v1r': (50,100),
    'v2r': (250,300),
    'goffset_hwing1': 0,
    'goffset_hwing2': 0,
    'goffset_vwing1': 0,
    'goffset_vwing2': 0,
    'polynom_h1': 1,
    'polynom_h2': 1,
    'polynom_v1': 1,
    'polynom_v2': 1,
    'pixcount_cutoff': 650,
    'target_name': 'noname',
    'airmass': 'noair'
}

# %%
raunche_list = []

# %%
raunche_list.append(raunche_def)

# %%
range(len(event_timestamp_list))
# Out:
# range(0, 65)

# %%
for i in range(len(event_timestamp_list)):
    raunche_data = {
    'timestamp': event_timestamp_list[i][0],
    'goffset_stellar_centroidx': 0,
    'goffset_stellar_centroidy': 0,
    'hafbox': 40,
    'bigbox': 250,
    'h1r': (50,100),
    'h2r': (250,300),
    'v1r': (50,100),
    'v2r': (250,300),
    'goffset_hwing1': 0,
    'goffset_hwing2': 0,
    'goffset_vwing1': 0,
    'goffset_vwing2': 0,
    'polynom_h1': 1,
    'polynom_h2': 1,
    'polynom_v1': 1,
    'polynom_v2': 1,
    'pixcount_cutoff': 650,
    'target_name': event_timestamp_list[i][1],
    'airmass': event_timestamp_list[i][2]
    }
    
    raunche_list.append(raunche_data)

# %%
with open(r'params/raunche.yaml', 'w') as file:
    documents = yaml.dump(raunche_list, file)

# %%
with open(r'params/raunche.yaml') as file:
    # The FullLoader parameter handles the conversion from YAML
    # scalar values to Python the dictionary format
    raunche_read_yaml = yaml.load(file, Loader=yaml.FullLoader)

# %%
raunche_list
# Out:
# [{'timestamp': 'default',
#   'goffset_stellar_centroidx': 0,
#   'goffset_stellar_centroidy': 0,
#   'hafbox': 40,
#   'bigbox': 250,
#   'h1r': (50, 100),
#   'h2r': (250, 300),
#   'v1r': (50, 100),
#   'v2r': (250, 300),
#   'goffset_hwing1': 0,
#   'goffset_hwing2': 0,
#   'goffset_vwing1': 0,
#   'goffset_vwing2': 0,
#   'polynom_h1': 1,
#   'polynom_h2': 1,
#   'polynom_v1': 1,
#   'polynom_v2': 1,
#   'pixcount_cutoff': 650,
#   'target_name': 'noname',
#   'airmass': 'noair'},
#  {'timestamp': '20200114.061041',
#   'goffset_stellar_centroidx': 0,
#   'goffset_stellar_centroidy': 0,
#   'hafbox': 40,
#   'bigbox': 250,
#   'h1r': (50, 100),
#   'h2r': (250, 300),
#   'v1r': (50, 100),
#   'v2r': (250, 300),
#   'goffset_hwing1': 0,
#   'goffset_hwing2': 0,
#   'goffset_vwing1': 0,
#   'goffset_vwing2': 0,
#   'polynom_h1': 1,
#   'polynom_h2': 1,
#   'polynom_v1': 1,
#   'polynom_v2': 1,
#   'pixcount_cutoff': 650,
#   'target_name': 'lam Tau - HD 25204',
# ...
